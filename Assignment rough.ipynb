# %% [markdown]
# # Replace Nan values with correct values

# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
# sl_no             215 non-null int64
# gender            215 non-null object
# ssc_p             215 non-null float64
# ssc_b             215 non-null object
# hsc_p             215 non-null float64
# hsc_b             215 non-null object
# hsc_s             215 non-null object
# degree_p          215 non-null float64
# degree_t          215 non-null object
# workex            215 non-null object
# etest_p           215 non-null float64
# specialisation    215 non-null object
# mba_p             215 non-null float64
# status            215 non-null object
# salary            148 non-null float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
#Null = Nothing #NonNuLL = Something #Nan = Nothing

# %%
#In salary has Nan values since all are filled with 215 rows but salary is only 148 so remaing Nan values found

# %%
dataset.isnull
# Out:
# <bound method DataFrame.isnull of      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull()
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0    False   False  False  False  False  False  False     False     False
# 1    False   False  False  False  False  False  False     False     False
# 2    False   False  False  False  False  False  False     False     False
# 3    False   False  False  False  False  False  False     False     False
# 4    False   False  False  False  False  False  False     False     False
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210  False   False  False  False  False  False  False     False     False
# 211  False   False  False  False  False  False  False     False     False
# 212  False   False  False  False  False  False  False     False     False
# 213  False   False  False  False  False  False  False     False     False
# 214  False   False  False  False  False  False  False     False     False
#
#      workex  etest_p  specialisation  mba_p  status  salary
# ...

# %%
#Here we have founded that True value is the Null value

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
#In detial we can lookup with in only slary data 67 entries are Nan data's

# %%
#Note dataset.isna().sum() and dataset.isnull.sum() are give the same result

# %%
#Still here not placed students are having Nan values

# %%
#Now replacing the Nan values into values

# %%
dataset['salary'].fillna(0,inplace=True)

# %%
#code explain: here dataset salary row we have to replace with nan values
#dataset['salary'].fillna = fillna is to fill the nan values
#fillna(0,inplace=True) = fill nan values to be 0 in the place of True present in the salary datas

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#Here we have the answer the nan values should be filled with 0's we can check with dataset.isnull()

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
# Here all values are zero also you can check with dataset.isnull() to find any true values present

# %%
dataset.isnull()
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0    False   False  False  False  False  False  False     False     False
# 1    False   False  False  False  False  False  False     False     False
# 2    False   False  False  False  False  False  False     False     False
# 3    False   False  False  False  False  False  False     False     False
# 4    False   False  False  False  False  False  False     False     False
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210  False   False  False  False  False  False  False     False     False
# 211  False   False  False  False  False  False  False     False     False
# 212  False   False  False  False  False  False  False     False     False
# 213  False   False  False  False  False  False  False     False     False
# 214  False   False  False  False  False  False  False     False     False
#
#      workex  etest_p  specialisation  mba_p  status  salary
# ...

# %%
# Since in the dataset there is no True values present and because True values are filled with values (0) so it is mentioned false

# %%
#Nan values are replaced

# %% [markdown]
# # How many of them are not placed

# %%
#Taking same dataset

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset['status'].sum()
# Out:
# 'PlacedPlacedPlacedNot PlacedPlacedNot PlacedNot PlacedPlacedPlacedNot PlacedPlacedPlacedNot PlacedPlacedNot PlacedPlacedPlacedNot PlacedNot PlacedPlacedPlacedPlacedPlacedPlacedPlacedNot PlacedPlacedPlacedPlacedNot PlacedPlacedNot PlacedPlacedPlacedNot PlacedPlacedNot PlacedPlacedPlacedPlacedPlacedNot PlacedNot PlacedPlacedPlacedNot PlacedNot PlacedPlacedPlacedNot PlacedPlacedNot PlacedNot PlacedPlacedPlacedPlacedPlacedPlacedPlacedPlacedPlacedPlacedPlacedNot PlacedPlacedNot PlacedPlacedPlacedNot PlacedPlacedPlacedPlacedPlacedPlacedPlacedNot PlacedPlacedPlacedPlacedNot PlacedPlacedPlacedNot PlacedPlacedPlacedPlacedPlacedNot PlacedPlacedPlacedPlacedNot PlacedPlacedNot PlacedPlacedPlacedPlacedNot PlacedPlacedNot PlacedNot PlacedPlacedPlacedPlacedPlacedNot PlacedNot PlacedPlacedPlacedNot PlacedPlacedNot PlacedPlacedPlacedPlacedPlacedPlacedPlacedPlacedPlacedNot PlacedPlacedPlacedPlacedPlacedPlacedPlacedPlacedPlacedPlacedNot PlacedPlacedPlacedPlacedPlacedPlacedNot PlacedPlacedPlacedPlacedP
# ...

# %%
dataset.status.sum
# Out:
# <bound method Series.sum of 0          Placed
# 1          Placed
# 2          Placed
# 3      Not Placed
# 4          Placed
#           ...
# 210        Placed
# 211        Placed
# 212        Placed
# 213        Placed
# 214    Not Placed
# Name: status, Length: 215, dtype: object>

# %%
dataset.status.count()
# Out:
# 215

# %%
dir(dataset)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
value_counts=dataset['status'].value_counts()
print(value_counts)
# Out:
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %%
#Here 148 students are placed and 67 students are not placed

# %% [markdown]
# # 3. Find the reason for non placement from the dataset?

# %%
#Since there are multiple factor that for non placing but according to dataset we can check few things with hsc_p and status comparison

# %% [markdown]
# # 4. What kind of relation between salary and mba_p

# %%
dataset.cov()
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -58.106028     -40.413645
# ssc_p       -52.641355     117.228377      60.348373      42.897137
# hsc_p       -58.106028      60.348373     118.755706      34.819820
# degree_p    -40.413645      42.897137      34.819820      54.151103
# etest_p      52.556168      37.659225      35.461678      21.929469
# mba_p         8.102336      24.535952      22.555846      17.272020
# salary    24490.654206  901754.893936  763359.777657  465131.504238
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  2.449065e+04
# ssc_p         37.659225      24.535952  9.017549e+05
# hsc_p         35.461678      22.555846  7.633598e+05
# degree_p      21.929469      17.272020  4.651315e+05
# etest_p      176.251018      16.886973  3.842344e+05
# mba_p         16.886973      34.028376  1.262455e+05
# ...

# %%
# since we got a value of 1.262455 *05 power
# it is a positive covariance value is in 1.262 since value is very low only with 10%

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
#Here correlated value is 0.139823
#Since it is a positive correlation directly proportional since it is very value 0.139823 with only 13.9%

# %% [markdown]
# # 5, Which specialization is getting minimum salary?

# %%
min=dataset["salary"]["specialisation"].min()
print(min)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11680\2556976100.py in <module>
# ----> 1 min=dataset["salary"]["specialisation"].min()
#       2 print(min)
#
# ~\.conda\envs\aiml\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# ~\.conda\envs\aiml\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
# ...

# %%
min=dataset["salary"]["specialisation"].min()
print("min")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11680\1164016588.py in <module>
# ----> 1 min=dataset["salary"]["specialisation"].min()
#       2 print("min")
#
# ~\.conda\envs\aiml\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# ~\.conda\envs\aiml\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
# ...

# %% [markdown]
# # 6 How many of them getting above 500000 salary?

# %%
value_counts=dataset['salary'].value_counts()
print(value_counts)
# Out:
# 0.0         67
# 300000.0    22
# 250000.0    18
# 240000.0    15
# 260000.0     7
# 265000.0     6
# 200000.0     6
# 360000.0     6
# 220000.0     5
# 275000.0     5
# 270000.0     4
# 210000.0     4
# 400000.0     4
# 350000.0     3
# 500000.0     3
# 216000.0     3
# 280000.0     2
# 218000.0     2
# 236000.0     2
# 204000.0     2
# 230000.0     2
# 252000.0     2
# 276000.0     2
# 290000.0     1
# 411000.0     1
# 393000.0     1
# 650000.0     1
# 278000.0     1
# 225000.0     1
# 336000.0     1
# 264000.0     1
# 940000.0     1
# 287000.0     1
# 380000.0     1
# 231000.0     1
# 320000.0     1
# 425000.0     1
# 690000.0     1
# 233000.0     1
# 295000.0     1
# 255000.0     1
# 450000.0     1
# 420000.0     1
# 268000.0     1
# 285000.0     1
# 340000.0     1
# Name: salary, dtype: int64

# %% [markdown]
# # 7. Test the analysis of Variance between etest_p and mba_p at significane level 5%. (Make decision using Hypothesis Testing)

# %%
import scipy.stats as stats

# %%
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
#Here we are getting pvalue =4.672 if p value <0.05 then we can Rejecy Null hypothesis still here pvalue is high so here Null hypothesis exist
